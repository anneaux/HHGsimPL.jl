# %%
include("../src/header/includes.jl")
# Out:
#   Activating project at `~/OneDrive/HHGsimPL.jl`
# LoadError: ArgumentError: Package QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] is required but does not seem to be installed:
#  - Run `Pkg.instantiate()` to install all recorded dependencies.
#
# in expression starting at /home/anne/OneDrive/HHGsimPL.jl/src/header/includes.jl:4
#
# Stacktrace:
#   [1] _require(pkg::Base.PkgId, env::String)
#     @ Base ./loading.jl:1920
#   [2] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base ./loading.jl:1806
#   [3] #invoke_in_world#3
#     @ Base ./essentials.jl:921 [inlined]
#   [4] invoke_in_world
#     @ Base ./essentials.jl:918 [inlined]
#   [5] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base ./loading.jl:1797
#   [6] macro expansion
#     @ Base ./loading.jl:1784 [inlined]
#   [7] macro expansion
#     @ Base ./lock.jl:267 [inlined]
#   [8] __require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:1747
#   [9] #invoke_in_world#3
# ...
